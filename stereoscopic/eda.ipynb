# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pygwalker as pyg

# %%
df_resp = pd.read_csv('./Dataset/responses.csv')
df_v = pd.read_csv('./Dataset/videos.csv')

# %%
df_resp.head()
# Out:
#   Which video did you just watch?  Age  Gender  \
# 0                          sharks   19    Male
# 1                      dunerovers   22    Male
# 2                         dotsall   23  Female
# 3                   woodencoaster   20  Female
# 4                         roadcar   21  Female
#
#   As a CHILD (before age 12), how often you Felt Sick or Nauseated: [Cars]  \
# 0                                Sometimes felt sick
# 1                               Frequently felt sick
# 2                                Sometimes felt sick
# 3                                   Rarely felt sick
# 4                                   Rarely felt sick
#
#   As a CHILD (before age 12), how often you Felt Sick or Nauseated: [Buses]  \
# 0                                   Rarely felt sick
# 1                                   Rarely felt sick
# 2                                   Rarely felt sick
# 3                                   Rarely felt sick
# ...

# %%
walker = pyg.walk(df_resp)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-000615ba35a1ca008pwMZU9F4AC3voXu" style="height: auto">\n    <head>…
# ERROR: kanaries_api_key is not valid.
# Please set kanaries_api_key first.
# If you are not kanaries user, please register it from 'https://kanaries.net/home/access'
# Then refer 'https://github.com/Kanaries/pygwalker/wiki/How-to-get-api-key-of-kanaries%3F' to set kanaries_api_key.
